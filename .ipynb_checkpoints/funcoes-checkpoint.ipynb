# %% [markdown]
# ### funções

# %% [markdown]
# #### A função é um bloco de código nomeado e padronizado com o objetivo de realizar alguma atividade no código geral, tornando mais legível e possibilitando o reaproveitamento do bloco de código, ou seja, programando de forma estruturada.

# %% [markdown]
# #### Usamos a palavra reservada def para definir o uso da função

# %%
def exibir_mensagem():
    print("Olá mundo!")

# %%
exibir_mensagem()
# Out:
# Olá mundo!

# %%
def exibir_mensagem(nome):
    print(f"Olá {nome}")

# %%
exibir_mensagem("Alexandre")
# Out:
# Olá Alexandre

# %%
def exibir_mensagem(nome="Anônimo"):  ### aqui declaramos automáticamente o nome como anônimo, evitando o erro, caso não digitado
    print(f"Olá {nome}")

# %%
exibir_mensagem()
# Out:
# Olá Anônimo

# %% [markdown]
# ### Como ver as funções ativas

# %% [markdown]
# #### Tipo 1

# %%
# %whos function
# Out:
# Variable          Type        Data/Info
# ---------------------------------------
# exibir_mensagem   function    <function exibir_mensagem at 0x000001153C25D9E0>

# %%
#### Tipo 2

# %%
# !python.exe -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\55119\appdata\local\programs\python\python313\lib\site-packages (25.2)
# Collecting pip
#   Downloading pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-25.3-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.8 MB 616.2 kB/s eta 0:00:03
#    ----------------- ---------------------- 0.8/1.8 MB 697.6 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.8/1.8 MB 697.6 kB/s eta 0:00:02
#    ----------------------- ---------------- 1.0/1.8 MB 769.3 kB/s eta 0:00:01
#    ----------------------- ---------------- 1.0/1.8 MB 769.3 kB/s eta 0:00:01
#    ----------------------------- ---------- 1.3/1.8 MB 717.4 kB/s eta 0:00:01
#    ----------------------------- ---------- 1.3/1.8 MB 717.4 kB/s eta 0:00:01
#    ----------------------------------- ---- 1.6/1.8 MB 655.7 kB/s eta 0:00:01
#    ----------------------------------- ---- 1.6/1.8 MB 655.7 kB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 665.0 kB/s  0:00:02
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 25.2
#     Uninstalling pip-25.2:
#       Successfully uninstalled pip-25.2
# Successfully installed pip-25.3
# WARNING: Ignoring invalid distribution ~ (C:\Users\55119\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\55119\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~pyterlab (C:\Users\55119\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Users\55119\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\55119\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~pyterlab (C:\Users\55119\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Users\55119\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\55119\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~pyterlab (C:\Users\55119\AppData\Local\Programs\Python\Python313\Lib\site-packages)

# %%
# !pip install lckr-jupyterlab-variableinspector
# Out:
# Collecting lckr-jupyterlab-variableinspector
# WARNING: Ignoring invalid distribution ~ (C:\Users\55119\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\55119\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~pyterlab (C:\Users\55119\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Users\55119\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\55119\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~pyterlab (C:\Users\55119\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Users\55119\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\55119\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~pyterlab (C:\Users\55119\AppData\Local\Programs\Python\Python313\Lib\site-packages)
#   Downloading lckr_jupyterlab_variableinspector-3.2.4-py3-none-any.whl.metadata (7.9 kB)
# Downloading lckr_jupyterlab_variableinspector-3.2.4-py3-none-any.whl (140 kB)
# Installing collected packages: lckr-jupyterlab-variableinspector
# Successfully installed lckr-jupyterlab-variableinspector-3.2.4
